# %% [markdown]
# # Simulación del Mundial 2026
#
# En este notebook se simulará el Mundial 2026 utilizando el modelo predictivo entrenado previamente.
#
# La simulación tendrá en cuenta:
#
# - Ranking FIFA
# - Puntos FIFA
# - Rating Elo
# - Forma reciente (últimos 5 partidos)
#
# Además, se incorporará el RMSE del modelo como fuente de incertidumbre para reflejar la variabilidad real de un partido de fútbol.
#
# El objetivo final es estimar la probabilidad de que cada selección alcance cada fase del torneo.

# %%
import pandas as pd
import numpy as np
import joblib

# %%
import warnings

warnings.filterwarnings(
    "ignore",
    category=UserWarning
)

# %%
dataset_modelado = pd.read_csv(
    "data/dataset_modelado.csv"
)

# %%
selecciones = pd.read_csv(
    "data/selecciones_actuales_mundial.csv"
)

selecciones.head()
# Out:
#              team  rank  total_points     elo        date  last5_points  \
# 0          Mexico  15.0       1675.75  1835.0  2025-11-18           4.0
# 1    South Africa  61.0       1426.73  1531.0  2025-12-29          10.0
# 2     South Korea  22.0       1599.45  1784.0  2025-11-18          10.0
# 3  Czech Republic  44.0       1487.00  1731.0  2025-11-17          11.0
# 4          Canada  27.0       1559.15  1802.0  2025-11-18           6.0
#
#    last5_goals_for  last5_goals_against  last5_goal_balance
# 0              3.0                  7.0                -4.0
# 1              8.0                  4.0                 4.0
# 2              9.0                  6.0                 3.0
# 3              6.0                  2.0                 4.0
# 4              3.0                  2.0                 1.0

# %%
selecciones.shape
# Out:
# (48, 9)

# %%
selecciones = selecciones.drop(
    columns=["date"]
)

selecciones.shape
# Out:
# (48, 8)

# %%
selecciones.head()
# Out:
#              team  rank  total_points     elo  last5_points  last5_goals_for  \
# 0          Mexico  15.0       1675.75  1835.0           4.0              3.0
# 1    South Africa  61.0       1426.73  1531.0          10.0              8.0
# 2     South Korea  22.0       1599.45  1784.0          10.0              9.0
# 3  Czech Republic  44.0       1487.00  1731.0          11.0              6.0
# 4          Canada  27.0       1559.15  1802.0           6.0              3.0
#
#    last5_goals_against  last5_goal_balance
# 0                  7.0                -4.0
# 1                  4.0                 4.0
# 2                  6.0                 3.0
# 3                  2.0                 4.0
# 4                  2.0                 1.0

# %%
selecciones.columns.tolist()
# Out:
# ['team',
#  'rank',
#  'total_points',
#  'elo',
#  'last5_points',
#  'last5_goals_for',
#  'last5_goals_against',
#  'last5_goal_balance']

# %%
modelo = joblib.load(
    "modelo_regresion_lineal.pkl"
)
scaler = joblib.load(
    "scaler.pkl"
)

# %% [markdown]
# ## Función para obtener los datos de una selección
#
# Para simular partidos necesitaremos acceder rápidamente a las características de cada selección.
#
# Esta función devolverá todas las variables de una selección concreta.

# %%
equipos_dict = {}

for _, fila in selecciones.iterrows():

    equipos_dict[
        fila["team"]
    ] = fila


def obtener_equipo(nombre):

    return equipos_dict[nombre]

# %%
obtener_equipo("Spain")
# Out:
# team                     Spain
# rank                       1.0
# total_points           1877.18
# elo                     2171.0
# last5_points              13.0
# last5_goals_for           17.0
# last5_goals_against        9.0
# last5_goal_balance         8.0
# Name: 28, dtype: object

# %% [markdown]
# ## Simulación de un partido
#
# Esta función utilizará el modelo entrenado para predecir la diferencia de goles entre dos selecciones.
#
# Posteriormente se añadirá un error aleatorio basado en el RMSE del modelo para reflejar la incertidumbre real de un partido de fútbol.
#
# Finalmente la diferencia de goles se transformará en un resultado concreto.

# %% [markdown]
# ## Construcción de las variables de un partido
#
# Para cada enfrentamiento se calcularán las diferencias entre ambas selecciones utilizando las mismas variables empleadas durante el entrenamiento del modelo.
#
# De esta forma la simulación utilizará exactamente la misma información que el modelo vio durante su entrenamiento.

# %%
def crear_partido(equipo_local, equipo_visitante):

    local = obtener_equipo(equipo_local)
    visitante = obtener_equipo(equipo_visitante)

    return np.array([[
    1,
    10,
    local["rank"] - visitante["rank"],
    local["total_points"] - visitante["total_points"],
    local["elo"] - visitante["elo"],
    local["last5_points"] - visitante["last5_points"],
    local["last5_goals_for"] - visitante["last5_goals_for"],
    local["last5_goals_against"] - visitante["last5_goals_against"],
    local["last5_goal_balance"] - visitante["last5_goal_balance"]
]])

# %%
crear_partido(
    "Spain",
    "Uruguay"
)
# Out:
# array([[  1.  ,  10.  , -15.  , 204.56, 281.  ,   7.  ,  15.  ,   6.  ,
#           9.  ]])

# %% [markdown]
# ## Predicción de la diferencia de goles
#
# Utilizamos el modelo entrenado para predecir la diferencia de goles esperada entre dos selecciones.
#
# Posteriormente se añadirá una perturbación aleatoria basada en el RMSE para reflejar la incertidumbre de un partido real.

# %%
rmse = 1.6435
rmse_simulacion = 0.8

def simular_partido(equipo_local, equipo_visitante):

    partido = crear_partido(
        equipo_local,
        equipo_visitante
    )

    partido_scaled = scaler.transform(
        partido
    )

    prediccion = modelo.predict(
        partido_scaled
    )[0]

    error = np.random.normal(
        loc=0,
        scale=rmse_simulacion
    )

    diferencia_final = prediccion + error

    return diferencia_final

# %%
for _ in range(10):

    print(
        simular_partido(
            "Spain",
            "Uruguay"
        )
    )
# Out:
# 1.014303269235933
# 1.2166182527352256
# 1.6755433759491567
# -0.1592763426850643
# -0.1823711627374771
# 2.471920852822004
# 1.8480830343704355
# -0.44843449382590617
# 0.6808629345518458
# 1.65018617128786

# %%
dataset_modelado["goal_diff"].describe()
# Out:
# count    16704.000000
# mean         0.487787
# std          2.100759
# min        -14.000000
# 25%         -1.000000
# 50%          0.000000
# 75%          2.000000
# max         17.000000
# Name: goal_diff, dtype: float64

# %% [markdown]
# ## Conversión de diferencia de goles en marcador
#
# El modelo predice una diferencia de goles esperada.
#
# Para obtener resultados más realistas se transforma dicha diferencia en un marcador concreto, permitiendo calcular puntos, goles a favor, goles en contra y diferencia de goles para la clasificación del torneo.

# %%
def generar_marcador(diferencia):

    diferencia_redondeada = int(round(diferencia))

    if diferencia_redondeada == 0:

        goles = np.random.randint(0, 4)

        return goles, goles

    goles_base = np.random.randint(0, 3)

    if diferencia_redondeada > 0:

        return (
            goles_base + diferencia_redondeada,
            goles_base
        )

    else:

        return (
            goles_base,
            goles_base + abs(diferencia_redondeada)
        )

# %%
for _ in range(10):

    diferencia = simular_partido(
        "Spain",
        "Uruguay"
    )

    print(
        diferencia,
        generar_marcador(diferencia)
    )
# Out:
# 1.2431141630556546 (2, 1)
# 1.023869478142622 (2, 1)
# 0.8415167771771874 (3, 2)
# 0.5675395762927214 (1, 0)
# 0.9733408262429144 (2, 1)
# -0.3136063392359987 (0, 0)
# -0.1564341406663683 (0, 0)
# 0.3056705878282019 (3, 3)
# 0.7105839405032667 (3, 2)
# 0.1989917764326522 (2, 2)

# %% [markdown]
# ## Simulación de un grupo
#
# En esta sección simularemos todos los partidos de un grupo y construiremos la clasificación siguiendo las normas FIFA:
#
# 1. Puntos
# 2. Diferencia de goles
# 3. Goles a favor

# %%
grupo_a = [
    "Mexico",
    "South Africa",
    "South Korea",
    "Czech Republic"
]

# %%
tabla_grupo = pd.DataFrame({
    "team": grupo_a,
    "PJ": 0,
    "PG": 0,
    "PE": 0,
    "PP": 0,
    "GF": 0,
    "GC": 0,
    "DG": 0,
    "PTS": 0
})

tabla_grupo
# Out:
#              team  PJ  PG  PE  PP  GF  GC  DG  PTS
# 0          Mexico   0   0   0   0   0   0   0    0
# 1    South Africa   0   0   0   0   0   0   0    0
# 2     South Korea   0   0   0   0   0   0   0    0
# 3  Czech Republic   0   0   0   0   0   0   0    0

# %%
partidos_grupo = []

for i in range(len(grupo_a)):

    for j in range(i + 1, len(grupo_a)):

        partidos_grupo.append(
            (
                grupo_a[i],
                grupo_a[j]
            )
        )

partidos_grupo
# Out:
# [('Mexico', 'South Africa'),
#  ('Mexico', 'South Korea'),
#  ('Mexico', 'Czech Republic'),
#  ('South Africa', 'South Korea'),
#  ('South Africa', 'Czech Republic'),
#  ('South Korea', 'Czech Republic')]

# %% [markdown]
# ## Actualización de la clasificación
#
# Después de cada partido se actualizarán:
#
# - Partidos jugados
# - Victorias
# - Empates
# - Derrotas
# - Goles a favor
# - Goles en contra
# - Diferencia de goles
# - Puntos

# %%
def actualizar_tabla(
    tabla,
    local,
    visitante,
    goles_local,
    goles_visitante
):

    # Partidos jugados

    tabla.loc[local, "PJ"] += 1
    tabla.loc[visitante, "PJ"] += 1

    # Goles

    tabla.loc[local, "GF"] += goles_local
    tabla.loc[local, "GC"] += goles_visitante

    tabla.loc[visitante, "GF"] += goles_visitante
    tabla.loc[visitante, "GC"] += goles_local

    # Resultado

    if goles_local > goles_visitante:

        tabla.loc[local, "PG"] += 1
        tabla.loc[local, "PTS"] += 3

        tabla.loc[visitante, "PP"] += 1

    elif goles_local < goles_visitante:

        tabla.loc[visitante, "PG"] += 1
        tabla.loc[visitante, "PTS"] += 3

        tabla.loc[local, "PP"] += 1

    else:

        tabla.loc[local, "PE"] += 1
        tabla.loc[visitante, "PE"] += 1

        tabla.loc[local, "PTS"] += 1
        tabla.loc[visitante, "PTS"] += 1

    return tabla

# %% [markdown]
# ## Simulación completa del grupo
#
# Se simulan los seis partidos del grupo.
#
# Tras cada encuentro se actualiza la clasificación con los puntos y estadísticas correspondientes.

# %%
def simular_grupo(equipos):

    tabla = pd.DataFrame({
        "team": equipos,
        "PJ": 0,
        "PG": 0,
        "PE": 0,
        "PP": 0,
        "GF": 0,
        "GC": 0,
        "DG": 0,
        "PTS": 0
    })

    tabla = tabla.set_index(
        "team"
    )

    partidos = []

    resultados_partidos = []

    for i in range(len(equipos)):

        for j in range(i + 1, len(equipos)):

            partidos.append(
                (
                    equipos[i],
                    equipos[j]
                )
            )

    for local, visitante in partidos:

        diferencia = simular_partido(
            local,
            visitante
        )

        goles_local, goles_visitante = generar_marcador(
            diferencia
        )

        resultados_partidos.append(
            {
                "local": local,
                "visitante": visitante,
                "goles_local": goles_local,
                "goles_visitante": goles_visitante
            }
        )

        actualizar_tabla(
            tabla,
            local,
            visitante,
            goles_local,
            goles_visitante
        )

    tabla["DG"] = (
        tabla["GF"]
        - tabla["GC"]
    )

    tabla = tabla.sort_values(
        by=["PTS", "DG", "GF"],
        ascending=False
    )

    tabla = tabla.reset_index()

    tabla["posicion"] = range(
        1,
        len(tabla) + 1
    )

    tabla = tabla[
        [
            "posicion",
            "team",
            "PJ",
            "PG",
            "PE",
            "PP",
            "GF",
            "GC",
            "DG",
            "PTS"
        ]
    ]

    partidos_df = pd.DataFrame(
        resultados_partidos
    )

    return tabla, partidos_df

# %%
clasificacion, partidos = simular_grupo(
    grupo_a
)

# %%
partidos["resultado"] = (
    partidos["goles_local"].astype(str)
    + "-"
    + partidos["goles_visitante"].astype(str)
)

# %%
partidos
# Out:
#           local       visitante  goles_local  goles_visitante resultado
# 0        Mexico    South Africa            2                0       2-0
# 1        Mexico     South Korea            2                2       2-2
# 2        Mexico  Czech Republic            0                0       0-0
# 3  South Africa     South Korea            3                3       3-3
# 4  South Africa  Czech Republic            0                2       0-2
# 5   South Korea  Czech Republic            2                2       2-2

# %%
clasificacion
# Out:
#    posicion            team  PJ  PG  PE  PP  GF  GC  DG  PTS
# 0         1          Mexico   3   1   2   0   4   2   2    5
# 1         2  Czech Republic   3   1   2   0   4   2   2    5
# 2         3     South Korea   3   0   3   0   7   7   0    3
# 3         4    South Africa   3   0   1   2   3   7  -4    1

# %% [markdown]
# ## Obtener clasificados de un grupo
#
# Una vez simulado un grupo, necesitamos identificar:
#
# - 1º clasificado
# - 2º clasificado
# - 3º clasificado
# - 4º clasificado
#
# Esta información será necesaria posteriormente para:
#
# - Clasificados directos (1º y 2º)
# - Ranking de mejores terceros
# - Cruces de eliminación directa

# %%
def obtener_clasificados(clasificacion):

    primero = clasificacion.iloc[0]
    segundo = clasificacion.iloc[1]
    tercero = clasificacion.iloc[2]
    cuarto = clasificacion.iloc[3]

    return primero, segundo, tercero, cuarto

# %%
primero, segundo, tercero, cuarto = obtener_clasificados(
    clasificacion
)

# %%
print("1º:", primero["team"])
print("2º:", segundo["team"])
print("3º:", tercero["team"])
print("4º:", cuarto["team"])
# Out:
# 1º: Mexico
# 2º: Czech Republic
# 3º: South Korea
# 4º: South Africa

# %% [markdown]
# ## Definición de los grupos del Mundial
#
# Vamos a almacenar los 12 grupos del Mundial en un diccionario.
#
# Esto permitirá recorrer todos los grupos automáticamente y simular toda la fase de grupos mediante un único bucle.

# %%
grupos = {
    "A": ["Mexico", "South Africa", "South Korea", "Czech Republic"],

    "B": ["Canada", "Bosnia and Herzegovina", "Qatar", "Switzerland"],

    "C": ["Brazil", "Morocco", "Haiti", "Scotland"],

    "D": ["United States", "Paraguay", "Australia", "Turkey"],

    "E": ["Germany", "Curacao", "Ivory Coast", "Ecuador"],

    "F": ["Netherlands", "Japan", "Sweden", "Tunisia"],

    "G": ["Belgium", "Egypt", "Iran", "New Zealand"],

    "H": ["Spain", "Cape Verde", "Saudi Arabia", "Uruguay"],

    "I": ["France", "Senegal", "Iraq", "Norway"],

    "J": ["Argentina", "Algeria", "Austria", "Jordan"],

    "K": ["Portugal", "DR Congo", "Uzbekistan", "Colombia"],

    "L": ["England", "Croatia", "Ghana", "Panama"]
}

# %% [markdown]
# ## Simulación completa de la fase de grupos
#
# Se simularán automáticamente los 12 grupos del Mundial.
#
# Para cada grupo se almacenará:
#
# - Clasificación final
# - Resultados de los partidos
# - Primer clasificado
# - Segundo clasificado
# - Tercer clasificado
# - Cuarto clasificado

# %%
def simular_fase_grupos(grupos):

    clasificaciones = {}

    partidos_grupos = {}

    primeros = []

    segundos = []

    terceros = []

    cuartos = []

    for nombre_grupo, equipos in grupos.items():

        clasificacion, partidos = simular_grupo(
            equipos
        )

        clasificaciones[nombre_grupo] = clasificacion

        partidos_grupos[nombre_grupo] = partidos

        primero = clasificacion.iloc[0].copy()
        primero["grupo"] = nombre_grupo
        primeros.append(primero)

        segundo = clasificacion.iloc[1].copy()
        segundo["grupo"] = nombre_grupo
        segundos.append(segundo)

        tercero = clasificacion.iloc[2].copy()
        tercero["grupo"] = nombre_grupo
        terceros.append(tercero)

        cuarto = clasificacion.iloc[3].copy()
        cuarto["grupo"] = nombre_grupo
        cuartos.append(cuarto)

    primeros = pd.DataFrame(primeros)

    segundos = pd.DataFrame(segundos)

    terceros = pd.DataFrame(terceros)

    cuartos = pd.DataFrame(cuartos)

    return (
        clasificaciones,
        partidos_grupos,
        primeros,
        segundos,
        terceros,
        cuartos
    )

# %%
(
    clasificaciones,
    partidos_grupos,
    primeros,
    segundos,
    terceros,
    cuartos
) = simular_fase_grupos(
    grupos
)

# %%
clasificaciones["A"]
# Out:
#    posicion            team  PJ  PG  PE  PP  GF  GC  DG  PTS
# 0         1     South Korea   3   2   1   0   4   1   3    7
# 1         2  Czech Republic   3   1   1   1   3   4  -1    4
# 2         3          Mexico   3   0   2   1   3   4  -1    2
# 3         4    South Africa   3   0   2   1   2   3  -1    2

# %%
clasificaciones["H"]
# Out:
#    posicion          team  PJ  PG  PE  PP  GF  GC  DG  PTS
# 0         1         Spain   3   3   0   0   7   1   6    9
# 1         2       Uruguay   3   2   0   1   8   6   2    6
# 2         3  Saudi Arabia   3   1   0   2   3   6  -3    3
# 3         4    Cape Verde   3   0   0   3   2   7  -5    0

# %%
partidos_grupos["H"]
# Out:
#           local     visitante  goles_local  goles_visitante
# 0         Spain    Cape Verde            2                0
# 1         Spain  Saudi Arabia            3                0
# 2         Spain       Uruguay            2                1
# 3    Cape Verde  Saudi Arabia            0                1
# 4    Cape Verde       Uruguay            2                4
# 5  Saudi Arabia       Uruguay            2                3

# %%
primeros[["team","PTS","DG","GF"]]
# Out:
#           team  PTS  DG  GF
# 0  South Korea    7   3   4
# 0  Switzerland    7   3  10
# 0       Brazil    7   2   5
# 0       Turkey    6   2   8
# 0      Ecuador    9   5  10
# 0  Netherlands    9   4   5
# 0      Belgium    7   3   7
# 0        Spain    9   6   7
# 0       Norway    9   4   4
# 0    Argentina    9   6  10
# 0     Portugal    7   2   4
# 0      England    9   3   7

# %%
terceros[["team","PTS","DG","GF"]]
# Out:
#                      team  PTS  DG  GF
# 2                  Mexico    2  -1   3
# 2  Bosnia and Herzegovina    2  -2   8
# 2                Scotland    4   1   6
# 2           United States    4   0   5
# 2                 Curacao    1  -3   5
# 2                   Japan    4   0   3
# 2                   Egypt    2  -2   2
# 2            Saudi Arabia    3  -3   3
# 2                 Senegal    1  -2   3
# 2                 Austria    2  -2   7
# 2                Colombia    4   0   4
# 2                   Ghana    3  -3   2

# %% [markdown]
# ## Selección de los 8 mejores terceros
#
# Los terceros de cada grupo se ordenan utilizando los criterios FIFA:
#
# 1. Puntos
# 2. Diferencia de goles
# 3. Goles a favor
#
# Los 8 mejores avanzan a dieciseisavos de final.

# %%
ranking_terceros = terceros.sort_values(
    by=["PTS", "DG", "GF"],
    ascending=False
).reset_index(drop=True)

ranking_terceros
# Out:
#     posicion                    team  PJ  PG  PE  PP  GF  GC  DG  PTS grupo
# 0          3                Scotland   3   1   1   1   6   5   1    4     C
# 1          3           United States   3   1   1   1   5   5   0    4     D
# 2          3                Colombia   3   1   1   1   4   4   0    4     K
# 3          3                   Japan   3   1   1   1   3   3   0    4     F
# 4          3            Saudi Arabia   3   1   0   2   3   6  -3    3     H
# 5          3                   Ghana   3   1   0   2   2   5  -3    3     L
# 6          3                  Mexico   3   0   2   1   3   4  -1    2     A
# 7          3  Bosnia and Herzegovina   3   0   2   1   8  10  -2    2     B
# 8          3                 Austria   3   0   2   1   7   9  -2    2     J
# 9          3                   Egypt   3   0   2   1   2   4  -2    2     G
# 10         3                 Senegal   3   0   1   2   3   5  -2    1     I
# 11         3                 Curacao   3   0   1   2   5   8  -3    1     E

# %%
ranking_primeros = primeros.sort_values(
    by=["PTS", "DG", "GF"],
    ascending=False
).reset_index(drop=True)

ranking_primeros
# Out:
#     posicion         team  PJ  PG  PE  PP  GF  GC  DG  PTS grupo
# 0          1    Argentina   3   3   0   0  10   4   6    9     J
# 1          1        Spain   3   3   0   0   7   1   6    9     H
# 2          1      Ecuador   3   3   0   0  10   5   5    9     E
# 3          1  Netherlands   3   3   0   0   5   1   4    9     F
# 4          1       Norway   3   3   0   0   4   0   4    9     I
# 5          1      England   3   3   0   0   7   4   3    9     L
# 6          1  Switzerland   3   2   1   0  10   7   3    7     B
# 7          1      Belgium   3   2   1   0   7   4   3    7     G
# 8          1  South Korea   3   2   1   0   4   1   3    7     A
# 9          1       Brazil   3   2   1   0   5   3   2    7     C
# 10         1     Portugal   3   2   1   0   4   2   2    7     K
# 11         1       Turkey   3   2   0   1   8   6   2    6     D

# %%
mejores_terceros = ranking_terceros.head(8)

mejores_terceros[
    ["team", "PTS", "DG", "GF"]
]
# Out:
#                      team  PTS  DG  GF
# 0                Scotland    4   1   6
# 1           United States    4   0   5
# 2                Colombia    4   0   4
# 3                   Japan    4   0   3
# 4            Saudi Arabia    3  -3   3
# 5                   Ghana    3  -3   2
# 6                  Mexico    2  -1   3
# 7  Bosnia and Herzegovina    2  -2   8

# %%
terceros_eliminados = ranking_terceros.tail(4)

terceros_eliminados[
    ["team", "PTS", "DG", "GF"]
]
# Out:
#        team  PTS  DG  GF
# 8   Austria    2  -2   7
# 9     Egypt    2  -2   2
# 10  Senegal    1  -2   3
# 11  Curacao    1  -3   5

# %%
primeros.head()
# Out:
#    posicion         team  PJ  PG  PE  PP  GF  GC  DG  PTS grupo
# 0         1  South Korea   3   2   1   0   4   1   3    7     A
# 0         1  Switzerland   3   2   1   0  10   7   3    7     B
# 0         1       Brazil   3   2   1   0   5   3   2    7     C
# 0         1       Turkey   3   2   0   1   8   6   2    6     D
# 0         1      Ecuador   3   3   0   0  10   5   5    9     E

# %%
terceros.head()
# Out:
#    posicion                    team  PJ  PG  PE  PP  GF  GC  DG  PTS grupo
# 2         3                  Mexico   3   0   2   1   3   4  -1    2     A
# 2         3  Bosnia and Herzegovina   3   0   2   1   8  10  -2    2     B
# 2         3                Scotland   3   1   1   1   6   5   1    4     C
# 2         3           United States   3   1   1   1   5   5   0    4     D
# 2         3                 Curacao   3   0   1   2   5   8  -3    1     E

# %% [markdown]
# ## Preparación de los cruces de dieciseisavos
#
# Ya conocemos los 32 equipos clasificados:
#
# - 12 primeros de grupo
# - 12 segundos de grupo
# - 8 mejores terceros
#
# Para construir los cruces oficiales del Mundial necesitamos poder acceder rápidamente a cualquier clasificado mediante:
#
# - Grupo
# - Posición obtenida
#
# Por ejemplo:
#
# - 1º Grupo A
# - 2º Grupo H
# - 3º Grupo E
#
# Para ello se crea un diccionario que relaciona cada combinación (grupo, posición) con el nombre de la selección clasificada.

# %%
clasificados = pd.concat(
    [
        primeros.assign(tipo="1º"),
        segundos.assign(tipo="2º"),
        mejores_terceros.assign(tipo="3º")
    ],
    ignore_index=True
)

clasificados
# Out:
#     posicion                    team  PJ  PG  PE  PP  GF  GC  DG  PTS grupo  \
# 0          1             South Korea   3   2   1   0   4   1   3    7     A
# 1          1             Switzerland   3   2   1   0  10   7   3    7     B
# 2          1                  Brazil   3   2   1   0   5   3   2    7     C
# 3          1                  Turkey   3   2   0   1   8   6   2    6     D
# 4          1                 Ecuador   3   3   0   0  10   5   5    9     E
# 5          1             Netherlands   3   3   0   0   5   1   4    9     F
# 6          1                 Belgium   3   2   1   0   7   4   3    7     G
# 7          1                   Spain   3   3   0   0   7   1   6    9     H
# 8          1                  Norway   3   3   0   0   4   0   4    9     I
# 9          1               Argentina   3   3   0   0  10   4   6    9     J
# 10         1                Portugal   3   2   1   0   4   2   2    7     K
# 11         1                 England   3   3   0   0   7   4   3    9     L
# 12         2          Czech Republic   3   1   1   1   3   4  -1    4     A
# 13         2                  Canada   3   1   2   0   8   6   2    5     B
# 14         2                 Morocco   3   1   2   0   5   4   1    5     C
# 15         2               Australia   3   1   2   0   7   6   1    5     D
# 16         2                 Germany   3   2   0   1   7   6   1    6     E
# 17         2                 Tunisia   3   1   1   1   4   4   0    4     F
# 18         2                    Iran   3   1   2   0   4   3   1    5     G
# 19         2                 Uruguay   3   2   0   1   8   6   2    6     H
# 20         2                  France   3   2   0   1   2   1   1    6     I
# 21         2                 Algeria   3   0   2   1   8   9  -1    2     J
# 22         2              Uzbekistan   3   1   1   1   5   5   0    4     K
# 23         2                 Croatia   3   2   0   1   8   4   4    6     L
# 24         3                Scotland   3   1   1   1   6   5   1    4     C
# 25         3           United States   3   1   1   1   5   5   0    4     D
# 26         3                Colombia   3   1   1   1   4   4   0    4     K
# 27         3                   Japan   3   1   1   1   3   3   0    4     F
# 28         3            Saudi Arabia   3   1   0   2   3   6  -3    3     H
# 29         3                   Ghana   3   1   0   2   2   5  -3    3     L
# 30         3                  Mexico   3   0   2   1   3   4  -1    2     A
# 31         3  Bosnia and Herzegovina   3   0   2   1   8  10  -2    2     B
#
#    tipo
# 0    1º
# 1    1º
# 2    1º
# 3    1º
# 4    1º
# 5    1º
# 6    1º
# 7    1º
# 8    1º
# 9    1º
# 10   1º
# 11   1º
# 12   2º
# 13   2º
# 14   2º
# 15   2º
# 16   2º
# 17   2º
# 18   2º
# 19   2º
# 20   2º
# 21   2º
# 22   2º
# 23   2º
# 24   3º
# 25   3º
# 26   3º
# 27   3º
# 28   3º
# 29   3º
# 30   3º
# 31   3º

# %%
clasificados.shape
# Out:
# (32, 12)

# %%
clasificados[
    ["grupo", "tipo", "team"]
].sort_values(
    by=["grupo", "tipo"]
)
# Out:
#    grupo tipo                    team
# 0      A   1º             South Korea
# 12     A   2º          Czech Republic
# 30     A   3º                  Mexico
# 1      B   1º             Switzerland
# 13     B   2º                  Canada
# 31     B   3º  Bosnia and Herzegovina
# 2      C   1º                  Brazil
# 14     C   2º                 Morocco
# 24     C   3º                Scotland
# 3      D   1º                  Turkey
# 15     D   2º               Australia
# 25     D   3º           United States
# 4      E   1º                 Ecuador
# 16     E   2º                 Germany
# 5      F   1º             Netherlands
# 17     F   2º                 Tunisia
# 27     F   3º                   Japan
# 6      G   1º                 Belgium
# 18     G   2º                    Iran
# 7      H   1º                   Spain
# 19     H   2º                 Uruguay
# 28     H   3º            Saudi Arabia
# 8      I   1º                  Norway
# 20     I   2º                  France
# 9      J   1º               Argentina
# 21     J   2º                 Algeria
# 10     K   1º                Portugal
# 22     K   2º              Uzbekistan
# 26     K   3º                Colombia
# 11     L   1º                 England
# 23     L   2º                 Croatia
# 29     L   3º                   Ghana

# %%
terceros_clasificados = (
    mejores_terceros["grupo"]
    .sort_values()
    .tolist()
)

terceros_clasificados
# Out:
# ['A', 'B', 'C', 'D', 'F', 'H', 'K', 'L']

# %%
equipos_por_grupo = {}

for _, fila in clasificados.iterrows():

    grupo = fila["grupo"]
    tipo = fila["tipo"]

    equipos_por_grupo[(grupo, tipo)] = fila["team"]

# %%
equipos_por_grupo[("A", "1º")]
# Out:
# 'South Korea'

# %%
equipos_por_grupo[("A", "2º")]
# Out:
# 'Czech Republic'

# %%
equipos_por_grupo[("A", "3º")]
# Out:
# 'Mexico'

# %% [markdown]
# ## Función auxiliar para obtener clasificados
#
# Esta función simplifica la lectura de los cruces.
#
# En lugar de escribir:
#
# equipos_por_grupo[("A","1º")]
#
# podremos escribir:
#
# obtener_equipo("A","1º")
#
# haciendo el código de los cruces mucho más legible.

# %%
def obtener_clasificado(grupo, posicion):

    return equipos_por_grupo[
        (grupo, posicion)
    ]

# %%
obtener_clasificado(
    "A",
    "1º"
)
# Out:
# 'South Korea'

# %% [markdown]
# QUEDA VER BIEN LO DE LOS MEJROES 3 PORQUE PUEDE GENERAR DUDAS, EN FUNCION DE QUIENES PASEN

# %% [markdown]
# ## Construcción de los cruces oficiales
#
# Se crea la estructura de los partidos de dieciseisavos.
#
# Los cruces fijos entre primeros y segundos de grupo pueden generarse directamente.
#
# Los cruces que dependen de terceros clasificados se completarán posteriormente mediante una función específica.

# %% [markdown]
# ## Completar los 16 partidos de dieciseisavos
#
# Los cruces que dependen de los mejores terceros se asignarán temporalmente utilizando el ranking de terceros.
#
# Posteriormente sustituiremos esta lógica por la tabla oficial FIFA.

# %%
terceros_ordenados = (
    mejores_terceros["team"]
    .tolist()
)

terceros_ordenados
# Out:
# ['Scotland',
#  'United States',
#  'Colombia',
#  'Japan',
#  'Saudi Arabia',
#  'Ghana',
#  'Mexico',
#  'Bosnia and Herzegovina']

# %%
cruces_terceros = {

    74: (
        equipos_por_grupo[("E", "1º")],
        terceros_ordenados[0]
    ),

    77: (
        equipos_por_grupo[("I", "1º")],
        terceros_ordenados[1]
    ),

    79: (
        equipos_por_grupo[("A", "1º")],
        terceros_ordenados[2]
    ),

    80: (
        equipos_por_grupo[("L", "1º")],
        terceros_ordenados[3]
    ),

    81: (
        equipos_por_grupo[("D", "1º")],
        terceros_ordenados[4]
    ),

    82: (
        equipos_por_grupo[("G", "1º")],
        terceros_ordenados[5]
    ),

    85: (
        equipos_por_grupo[("B", "1º")],
        terceros_ordenados[6]
    ),

    87: (
        equipos_por_grupo[("K", "1º")],
        terceros_ordenados[7]
    )
}

# %%
cruces_fijos = {

    73: ("A", "2º", "B", "2º"),

    75: ("F", "1º", "C", "2º"),

    76: ("C", "1º", "F", "2º"),

    78: ("E", "2º", "I", "2º"),

    83: ("K", "2º", "L", "2º"),

    84: ("H", "1º", "J", "2º"),

    86: ("J", "1º", "H", "2º"),

    88: ("D", "2º", "G", "2º")
}

# %%
def generar_cruces_fijos():

    partidos = []

    for numero, cruce in cruces_fijos.items():

        grupo1, pos1, grupo2, pos2 = cruce

        partidos.append({

            "partido": numero,

            "local": obtener_clasificado(
                grupo1,
                pos1
            ),

            "visitante": obtener_clasificado(
                grupo2,
                pos2
            )
        })

    return pd.DataFrame(
        partidos
    ).sort_values(
        "partido"
    )

# %%
cruces_16avos = generar_cruces_fijos()

cruces_16avos
# Out:
#    partido           local visitante
# 0       73  Czech Republic    Canada
# 1       75     Netherlands   Morocco
# 2       76          Brazil   Tunisia
# 3       78         Germany    France
# 4       83      Uzbekistan   Croatia
# 5       84           Spain   Algeria
# 6       86       Argentina   Uruguay
# 7       88       Australia      Iran

# %% [markdown]
# ## Estructura oficial de los cruces
#
# Cada partido de eliminación directa se identifica mediante el número oficial FIFA.
#
# Esto permitirá construir automáticamente:
#
# - Dieciseisavos
# - Octavos
# - Cuartos
# - Semifinales
# - Final
#
# siguiendo exactamente el cuadro oficial del Mundial 2026.

# %%
partidos_eliminatoria = {}

# %%
for _, fila in cruces_16avos.iterrows():

    partidos_eliminatoria[
        fila["partido"]
    ] = {
        "local": fila["local"],
        "visitante": fila["visitante"]
    }

partidos_eliminatoria
# Out:
# {73: {'local': 'Czech Republic', 'visitante': 'Canada'},
#  75: {'local': 'Netherlands', 'visitante': 'Morocco'},
#  76: {'local': 'Brazil', 'visitante': 'Tunisia'},
#  78: {'local': 'Germany', 'visitante': 'France'},
#  83: {'local': 'Uzbekistan', 'visitante': 'Croatia'},
#  84: {'local': 'Spain', 'visitante': 'Algeria'},
#  86: {'local': 'Argentina', 'visitante': 'Uruguay'},
#  88: {'local': 'Australia', 'visitante': 'Iran'}}

# %%
for numero, (local, visitante) in cruces_terceros.items():

    partidos_eliminatoria[numero] = {

        "local": local,
        "visitante": visitante
    }

# %%
sorted(
    partidos_eliminatoria.keys()
)
# Out:
# [73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88]

# %%
partidos_eliminatoria[73]
# Out:
# {'local': 'Czech Republic', 'visitante': 'Canada'}

# %% [markdown]
# ## Simulación de partidos eliminatorios
#
# En las fases eliminatorias no puede haber empates.
#
# Si el partido termina empatado tras los 90 minutos, se simulará una prórroga y, si fuera necesario, una tanda de penaltis.
#
# Para simplificar el modelo, los empates se resolverán aleatoriamente entre ambos equipos.

# %%
def simular_eliminatoria(local, visitante):

    diferencia = simular_partido(
        local,
        visitante
    )

    goles_local, goles_visitante = generar_marcador(
        diferencia
    )

    if goles_local > goles_visitante:

        ganador = str(local)

    elif goles_visitante > goles_local:

        ganador = str(visitante)

    else:

        ganador = str (np.random.choice(
            [local, visitante])
        )

    return {
        "local": local,
        "visitante": visitante,
        "goles_local": goles_local,
        "goles_visitante": goles_visitante,
        "ganador": ganador
    }

# %%
for _ in range(5):

    print(
        simular_eliminatoria(
            "Spain",
            "Austria"
        )
    )
# Out:
# {'local': 'Spain', 'visitante': 'Austria', 'goles_local': 3, 'goles_visitante': 1, 'ganador': 'Spain'}
# {'local': 'Spain', 'visitante': 'Austria', 'goles_local': 4, 'goles_visitante': 2, 'ganador': 'Spain'}
# {'local': 'Spain', 'visitante': 'Austria', 'goles_local': 1, 'goles_visitante': 0, 'ganador': 'Spain'}
# {'local': 'Spain', 'visitante': 'Austria', 'goles_local': 2, 'goles_visitante': 1, 'ganador': 'Spain'}
# {'local': 'Spain', 'visitante': 'Austria', 'goles_local': 0, 'goles_visitante': 0, 'ganador': 'Spain'}

# %% [markdown]
# ## Almacenamiento de resultados eliminatorios
#
# Cada partido eliminatorio se almacenará utilizando su número oficial FIFA.
#
# Esto permitirá construir automáticamente las siguientes rondas utilizando los ganadores de los partidos anteriores.

# %%
resultados_eliminatoria = {}

# %%
resultado_73 = simular_eliminatoria(
    partidos_eliminatoria[73]["local"],
    partidos_eliminatoria[73]["visitante"]
)

resultado_73
# Out:
# {'local': 'Czech Republic',
#  'visitante': 'Canada',
#  'goles_local': 2,
#  'goles_visitante': 3,
#  'ganador': 'Canada'}

# %%
resultados_eliminatoria[73] = resultado_73

resultados_eliminatoria[73]
# Out:
# {'local': 'Czech Republic',
#  'visitante': 'Canada',
#  'goles_local': 2,
#  'goles_visitante': 3,
#  'ganador': 'Canada'}

# %%
resultados_eliminatoria[73]["ganador"]
# Out:
# 'Canada'

# %% [markdown]
# ## Simulación automática de las eliminatorias
#
# Vamos a crear una función que juegue un partido eliminatorio a partir de su número oficial FIFA.
#
# La función buscará los equipos participantes, simulará el partido y almacenará el ganador para que pueda utilizarse en rondas posteriores.

# %%
def jugar_partido_eliminatoria(numero_partido):

    local = partidos_eliminatoria[numero_partido]["local"]

    visitante = partidos_eliminatoria[numero_partido]["visitante"]

    resultado = simular_eliminatoria(
        local,
        visitante
    )

    resultados_eliminatoria[numero_partido] = resultado

    return resultado

# %%
jugar_partido_eliminatoria(73)
# Out:
# {'local': 'Czech Republic',
#  'visitante': 'Canada',
#  'goles_local': 1,
#  'goles_visitante': 1,
#  'ganador': 'Czech Republic'}

# %% [markdown]
# ## Obtener ganadores de partidos anteriores
#
# Las rondas siguientes utilizan ganadores de partidos previos.
#
# Por ello creamos una función que devuelve automáticamente el ganador de cualquier partido ya disputado.

# %%
def ganador(numero_partido):

    return resultados_eliminatoria[
        numero_partido
    ]["ganador"]

# %%
ganador(73)
# Out:
# 'Czech Republic'

# %% [markdown]
# ## Construcción automática de los octavos de final
#
# Según el cuadro oficial FIFA:
#
# - Partido 89 = Ganador 74 vs Ganador 77
# - Partido 90 = Ganador 73 vs Ganador 75
# - Partido 91 = Ganador 76 vs Ganador 78
# - Partido 92 = Ganador 79 vs Ganador 80
# - Partido 93 = Ganador 83 vs Ganador 84
# - Partido 94 = Ganador 81 vs Ganador 82
# - Partido 95 = Ganador 86 vs Ganador 88
# - Partido 96 = Ganador 85 vs Ganador 87

# %%
cruces_octavos = {

    89: (74, 77),
    90: (73, 75),
    91: (76, 78),
    92: (79, 80),

    93: (83, 84),
    94: (81, 82),
    95: (86, 88),
    96: (85, 87)
}

# %%
def jugar_octavo(numero_octavo):

    p1, p2 = cruces_octavos[numero_octavo]

    equipo1 = ganador(p1)

    equipo2 = ganador(p2)

    resultado = simular_eliminatoria(
        equipo1,
        equipo2
    )

    resultados_eliminatoria[numero_octavo] = resultado

    return resultado

# %%
for partido in range(73, 89):

    jugar_partido_eliminatoria(
        partido
    )

# %%
jugar_octavo(89)
# Out:
# {'local': 'Ecuador',
#  'visitante': 'Norway',
#  'goles_local': 0,
#  'goles_visitante': 1,
#  'ganador': 'Norway'}

# %% [markdown]
# ## Estructura de cuartos de final
#
# Según el cuadro oficial FIFA:
#
# - 97 = Ganador 89 vs Ganador 90
# - 98 = Ganador 93 vs Ganador 94
# - 99 = Ganador 91 vs Ganador 92
# - 100 = Ganador 95 vs Ganador 96

# %%
cruces_cuartos = {

    97: (89, 90),

    98: (93, 94),

    99: (91, 92),

    100: (95, 96)
}

# %% [markdown]
# ## Función para simular cuartos de final

# %%
def jugar_cuarto(numero_cuarto):

    p1, p2 = cruces_cuartos[numero_cuarto]

    equipo1 = ganador(p1)

    equipo2 = ganador(p2)

    resultado = simular_eliminatoria(
        equipo1,
        equipo2
    )

    resultados_eliminatoria[numero_cuarto] = resultado

    return resultado

# %% [markdown]
# Semifinales

# %%
cruces_semifinales = {

    101: (97, 98),

    102: (99, 100)
}

# %%
def jugar_semifinal(numero_semifinal):

    p1, p2 = cruces_semifinales[numero_semifinal]

    equipo1 = ganador(p1)

    equipo2 = ganador(p2)

    resultado = simular_eliminatoria(
        equipo1,
        equipo2
    )

    resultados_eliminatoria[numero_semifinal] = resultado

    return resultado

# %% [markdown]
# FINAL

# %%
def jugar_final():

    equipo1 = ganador(101)

    equipo2 = ganador(102)

    resultado = simular_eliminatoria(
        equipo1,
        equipo2
    )

    resultados_eliminatoria[104] = resultado

    return resultado

# %% [markdown]
# ## Simulación completa del cuadro eliminatorio
#
# Esta función jugará automáticamente todas las rondas hasta obtener el campeón.

# %%
def simular_fase_final():

    resultados_eliminatoria.clear()

    for partido in range(73, 89):

        jugar_partido_eliminatoria(
            partido
        )

    for partido in range(89, 97):

        jugar_octavo(
            partido
        )

    for partido in range(97, 101):

        jugar_cuarto(
            partido
        )

    jugar_semifinal(101)

    jugar_semifinal(102)

    final = jugar_final()

    return final

# %%
simular_fase_final()
# Out:
# {'local': 'Spain',
#  'visitante': 'England',
#  'goles_local': 2,
#  'goles_visitante': 0,
#  'ganador': 'Spain'}

# %% [markdown]
# # Simulación completa del Mundial
#
# Vamos a integrar todas las fases del torneo en una única función.
#
# Cada ejecución generará:
#
# - Fase de grupos
# - Clasificados
# - Mejores terceros
# - Cruces eliminatorios
# - Campeón

# %%
def simular_mundial():

    (
        clasificaciones,
        partidos_grupos,
        primeros,
        segundos,
        terceros,
        cuartos
    ) = simular_fase_grupos(
        grupos
    )

    ranking_terceros = (
        terceros
        .sort_values(
            by=["PTS", "DG", "GF"],
            ascending=False
        )
        .reset_index(
            drop=True
        )
    )

    mejores_terceros = (
        ranking_terceros.head(8)
    )

    equipos_por_grupo = {}

    for _, fila in primeros.iterrows():

        equipos_por_grupo[
            (fila["grupo"], "1º")
        ] = fila["team"]

    for _, fila in segundos.iterrows():

        equipos_por_grupo[
            (fila["grupo"], "2º")
        ] = fila["team"]

    for _, fila in mejores_terceros.iterrows():

        equipos_por_grupo[
            (fila["grupo"], "3º")
        ] = fila["team"]

    terceros_ordenados = (
        mejores_terceros["team"]
        .tolist()
    )

    cruces_terceros = {

        74: (
            equipos_por_grupo[("E", "1º")],
            terceros_ordenados[0]
        ),

        77: (
            equipos_por_grupo[("I", "1º")],
            terceros_ordenados[1]
        ),

        79: (
            equipos_por_grupo[("A", "1º")],
            terceros_ordenados[2]
        ),

        80: (
            equipos_por_grupo[("L", "1º")],
            terceros_ordenados[3]
        ),

        81: (
            equipos_por_grupo[("D", "1º")],
            terceros_ordenados[4]
        ),

        82: (
            equipos_por_grupo[("G", "1º")],
            terceros_ordenados[5]
        ),

        85: (
            equipos_por_grupo[("B", "1º")],
            terceros_ordenados[6]
        ),

        87: (
            equipos_por_grupo[("K", "1º")],
            terceros_ordenados[7]
        )
    }

    cruces_fijos = {

        73: (
            equipos_por_grupo[("A", "2º")],
            equipos_por_grupo[("B", "2º")]
        ),

        75: (
            equipos_por_grupo[("F", "1º")],
            equipos_por_grupo[("C", "2º")]
        ),

        76: (
            equipos_por_grupo[("C", "1º")],
            equipos_por_grupo[("F", "2º")]
        ),

        78: (
            equipos_por_grupo[("E", "2º")],
            equipos_por_grupo[("I", "2º")]
        ),

        83: (
            equipos_por_grupo[("K", "2º")],
            equipos_por_grupo[("L", "2º")]
        ),

        84: (
            equipos_por_grupo[("H", "1º")],
            equipos_por_grupo[("J", "2º")]
        ),

        86: (
            equipos_por_grupo[("J", "1º")],
            equipos_por_grupo[("H", "2º")]
        ),

        88: (
            equipos_por_grupo[("D", "2º")],
            equipos_por_grupo[("G", "2º")]
        )
    }

    partidos_eliminatoria = {}

    for numero, (local, visitante) in cruces_fijos.items():

        partidos_eliminatoria[numero] = {
            "local": local,
            "visitante": visitante
        }

    for numero, (local, visitante) in cruces_terceros.items():

        partidos_eliminatoria[numero] = {
            "local": local,
            "visitante": visitante
        }

    resultados_eliminatoria = {}

    def ganador(numero_partido):

        return resultados_eliminatoria[
            numero_partido
        ]["ganador"]

    def jugar(numero_partido):

        local = partidos_eliminatoria[
            numero_partido
        ]["local"]

        visitante = partidos_eliminatoria[
            numero_partido
        ]["visitante"]

        resultado = simular_eliminatoria(
            local,
            visitante
        )

        resultados_eliminatoria[
            numero_partido
        ] = resultado

    # Dieciseisavos

    for partido in range(73, 89):

        jugar(partido)

    # Octavos

    cruces_octavos = {

        89: (74, 77),
        90: (73, 75),
        91: (76, 78),
        92: (79, 80),

        93: (83, 84),
        94: (81, 82),
        95: (86, 88),
        96: (85, 87)
    }

    for partido, (p1, p2) in cruces_octavos.items():

        resultado = simular_eliminatoria(
            ganador(p1),
            ganador(p2)
        )

        resultados_eliminatoria[
            partido
        ] = resultado

    # Cuartos

    cruces_cuartos = {

        97: (89, 90),

        98: (93, 94),

        99: (91, 92),

        100: (95, 96)
    }

    for partido, (p1, p2) in cruces_cuartos.items():

        resultado = simular_eliminatoria(
            ganador(p1),
            ganador(p2)
        )

        resultados_eliminatoria[
            partido
        ] = resultado

    # Semifinales

    resultado = simular_eliminatoria(
        ganador(97),
        ganador(98)
    )

    resultados_eliminatoria[101] = resultado

    resultado = simular_eliminatoria(
        ganador(99),
        ganador(100)
    )

    resultados_eliminatoria[102] = resultado

    # Final

    final = simular_eliminatoria(
        ganador(101),
        ganador(102)
    )

    resultados_eliminatoria[104] = final

    return {

        "campeon":
            resultados_eliminatoria[104]["ganador"],

        "final":
            resultados_eliminatoria[104],

        "resultados":
            resultados_eliminatoria
    }

# %%
{
        "primeros": primeros,
        "segundos": segundos,
        "mejores_terceros": mejores_terceros,
        "equipos_por_grupo": equipos_por_grupo
    }
# Out:
# {'primeros':    posicion         team  PJ  PG  PE  PP  GF  GC  DG  PTS grupo
#  0         1  South Korea   3   2   1   0   4   1   3    7     A
#  0         1  Switzerland   3   2   1   0  10   7   3    7     B
#  0         1       Brazil   3   2   1   0   5   3   2    7     C
#  0         1       Turkey   3   2   0   1   8   6   2    6     D
#  0         1      Ecuador   3   3   0   0  10   5   5    9     E
#  0         1  Netherlands   3   3   0   0   5   1   4    9     F
#  0         1      Belgium   3   2   1   0   7   4   3    7     G
#  0         1        Spain   3   3   0   0   7   1   6    9     H
#  0         1       Norway   3   3   0   0   4   0   4    9     I
#  0         1    Argentina   3   3   0   0  10   4   6    9     J
#  0         1     Portugal   3   2   1   0   4   2   2    7     K
#  0         1      England   3   3   0   0   7   4   3    9     L,
#  'segundos':    posicion            team  PJ  PG  PE  PP  GF  GC  DG  PTS grupo
#  1         2  Czech Republic   3   1   1   1   3   4  -1    4     A
#  1         2          Canada   3   1   2   0   8   6   2    5     B
#  1         2         Morocco   3   1   2   0   5   4   1    5     C
#  1         2       Australia   3   1   2   0   7   6   1    5     D
#  1         2         Germany   3   2   0   1   7   6   1    6     E
#  1         2         Tunisia   3   1   1   1   4   4   0    4     F
#  1         2            Iran   3   1   2   0   4   3   1    5     G
#  1         2         Uruguay   3   2   0   1   8   6   2    6     H
#  1         2          France   3   2   0   1   2   1   1    6     I
#  1         2         Algeria   3   0   2   1   8   9  -1    2     J
#  1         2      Uzbekistan   3   1   1   1   5   5   0    4     K
#  1         2         Croatia   3   2   0   1   8   4   4    6     L,
#  'mejores_terceros':    posicion                    team  PJ  PG  PE  PP  GF  GC  DG  PTS grupo
#  0         3                Scotland   3   1   1   1   6   5   1    4     C
#  1         3           United States   3   1   1   1   5   5   0    4     D
#  2         3                Colombia   3   1   1   1   4   4   0    4     K
#  3         3                   Japan   3   1   1   1   3   3   0    4     F
#  4         3            Saudi Arabia   3   1   0   2   3   6  -3    3     H
#  5         3                   Ghana   3   1   0   2   2   5  -3    3     L
#  6         3                  Mexico   3   0   2   1   3   4  -1    2     A
#  7         3  Bosnia and Herzegovina   3   0   2   1   8  10  -2    2     B,
#  'equipos_por_grupo': {('A', '1º'): 'South Korea',
#   ('B', '1º'): 'Switzerland',
#   ('C', '1º'): 'Brazil',
#   ('D', '1º'): 'Turkey',
#   ('E', '1º'): 'Ecuador',
#   ('F', '1º'): 'Netherlands',
#   ('G', '1º'): 'Belgium',
#   ('H', '1º'): 'Spain',
#   ('I', '1º'): 'Norway',
#   ('J', '1º'): 'Argentina',
#   ('K', '1º'): 'Portugal',
#   ('L', '1º'): 'England',
#   ('A', '2º'): 'Czech Republic',
#   ('B', '2º'): 'Canada',
#   ('C', '2º'): 'Morocco',
#   ('D', '2º'): 'Australia',
#   ('E', '2º'): 'Germany',
#   ('F', '2º'): 'Tunisia',
#   ('G', '2º'): 'Iran',
#   ('H', '2º'): 'Uruguay',
#   ('I', '2º'): 'France',
#   ('J', '2º'): 'Algeria',
#   ('K', '2º'): 'Uzbekistan',
#   ('L', '2º'): 'Croatia',
#   ('C', '3º'): 'Scotland',
#   ('D', '3º'): 'United States',
#   ('K', '3º'): 'Colombia',
#   ('F', '3º'): 'Japan',
#   ('H', '3º'): 'Saudi Arabia',
#   ('L', '3º'): 'Ghana',
#   ('A', '3º'): 'Mexico',
#   ('B', '3º'): 'Bosnia and Herzegovina'}}

# %%
resultado = simular_mundial()

# %%
resultado["campeon"]
# Out:
# 'Argentina'

# %%
import time

inicio = time.time()

for _ in range(100):

    simular_fase_grupos(grupos)

print(
    round(time.time() - inicio, 2)
)
# Out:
# 33.94

# %%
resultado["final"]
# Out:
# {'local': 'Netherlands',
#  'visitante': 'Portugal',
#  'goles_local': 0,
#  'goles_visitante': 0,
#  'ganador': 'Netherlands'}

# %%
for _ in range(5):

    print(
        simular_mundial()["campeon"]
    )
# Out:
# Portugal
# Argentina
# Norway
# Spain
# Colombia

# %%
for _ in range(5):

    resultado = simular_mundial()

    print(
        resultado["final"]
    )
# Out:
# {'local': 'Spain', 'visitante': 'Argentina', 'goles_local': 3, 'goles_visitante': 3, 'ganador': 'Spain'}
# {'local': 'Netherlands', 'visitante': 'Argentina', 'goles_local': 1, 'goles_visitante': 2, 'ganador': 'Argentina'}
# {'local': 'Spain', 'visitante': 'Argentina', 'goles_local': 2, 'goles_visitante': 1, 'ganador': 'Spain'}
# {'local': 'Netherlands', 'visitante': 'Paraguay', 'goles_local': 2, 'goles_visitante': 1, 'ganador': 'Netherlands'}
# {'local': 'Norway', 'visitante': 'England', 'goles_local': 2, 'goles_visitante': 3, 'ganador': 'England'}

# %%
for _ in range(100):

    print(
        simular_mundial()["campeon"]
    )
# Out:
# England
# Colombia
# England
# Uruguay
# Netherlands
# Argentina
# Argentina
# Argentina
# Netherlands
# Argentina
# Brazil
# Brazil
# France
# Germany
# Spain
# Ecuador
# Argentina
# Spain
# Belgium
# Spain
# Colombia
# England
# Germany
# Colombia
# Argentina
# Argentina
# Spain
# Colombia
# France
# Argentina
# England
# Germany
# Argentina
# Uruguay
# Spain
# Argentina
# Spain
# Netherlands
# Argentina
# Argentina
# Spain
# France
# Spain
# England
# Spain
# Senegal
# Spain
# Netherlands
# Netherlands
# England
# Brazil
# Spain
# Portugal
# Netherlands
# Ecuador
# Argentina
# Argentina
# Spain
# Spain
# France
# Argentina
# Spain
# Colombia
# Argentina
# Argentina
# Norway
# England
# Paraguay
# Portugal
# Senegal
# Switzerland
# Argentina
# Argentina
# Portugal
# Argentina
# Switzerland
# Norway
# Ecuador
# England
# England
# France
# Colombia
# Spain
# Netherlands
# Brazil
# Argentina
# Argentina
# England
# Netherlands
# Spain
# Argentina
# England
# Brazil
# Netherlands
# Spain
# Spain
# Argentina
# England
# Colombia
# Argentina

# %%
from collections import Counter

campeones = []

for _ in range(100):

    campeones.append(
        simular_mundial()["campeon"]
    )

Counter(campeones).most_common(20)
# Out:
# [('Spain', 26),
#  ('Argentina', 19),
#  ('England', 16),
#  ('Netherlands', 10),
#  ('Colombia', 8),
#  ('France', 6),
#  ('Ecuador', 3),
#  ('Belgium', 2),
#  ('Brazil', 2),
#  ('Turkey', 2),
#  ('Japan', 2),
#  ('Norway', 1),
#  ('Paraguay', 1),
#  ('Switzerland', 1),
#  ('Portugal', 1)]

# %%
import time

tabla_test = pd.DataFrame({
    "team": ["A", "B", "C", "D"],
    "PJ": 0,
    "PG": 0,
    "PE": 0,
    "PP": 0,
    "GF": 0,
    "GC": 0,
    "DG": 0,
    "PTS": 0
})

tabla_test = tabla_test.set_index(
    "team"
)

inicio = time.time()

for _ in range(10000):

    tabla = tabla_test.copy()

    actualizar_tabla(
        tabla,
        "A",
        "B",
        2,
        1
    )

print(
    round(
        time.time() - inicio,
        2
    )
)
# Out:
# 12.6

# %%
import time

tabla_test = pd.DataFrame({
    "team": ["A", "B", "C", "D"],
    "PJ": 0,
    "PG": 0,
    "PE": 0,
    "PP": 0,
    "GF": 0,
    "GC": 0,
    "DG": 0,
    "PTS": 0
})

inicio = time.time()

for _ in range(10000):

    actualizar_tabla(
        tabla_test.copy(),
        "A",
        "B",
        2,
        1
    )

print(time.time() - inicio)
# Out:
# 138.43099355697632

# %%
from collections import Counter

campeones = []

for _ in range(1000):

    campeones.append(
        simular_mundial()["campeon"]
    )

ranking = Counter(
    campeones
).most_common(20)

ranking
# Out:
# [('Spain', 251),
#  ('Argentina', 230),
#  ('England', 143),
#  ('France', 73),
#  ('Netherlands', 64),
#  ('Colombia', 45),
#  ('Croatia', 32),
#  ('Ecuador', 31),
#  ('Brazil', 28),
#  ('Portugal', 26),
#  ('Switzerland', 12),
#  ('Turkey', 12),
#  ('Norway', 11),
#  ('Germany', 10),
#  ('Japan', 9),
#  ('Uruguay', 5),
#  ('Canada', 4),
#  ('Paraguay', 4),
#  ('Belgium', 3),
#  ('Mexico', 2)]

# %%
import time

inicio = time.time()

for _ in range(10000):

    simular_partido(
        "Spain",
        "Argentina"
    )

print(time.time() - inicio)
# Out:
# 3.8821516036987305

# %%
import time

inicio = time.time()

for _ in range(10000):

    simular_partido(
        "Spain",
        "Argentina"
    )

print(
    round(
        time.time() - inicio,
        2
    )
)
# Out:
# 2.73

# %%
import time

inicio = time.time()

for _ in range(100):

    simular_fase_grupos(
        grupos
    )

print(
    round(
        time.time() - inicio,
        2
    )
)
# Out:
# 117.06

# %%
import time

inicio = time.time()

for _ in range(100):

    simular_mundial()

print(
    round(
        time.time() - inicio,
        2
    )
)
# Out:
# 105.32

# %%
resultado = simular_mundial()

len(
    resultado["resultados"]
)
# Out:
# 31

# %%
resultado.keys()
# Out:
# dict_keys(['primeros', 'segundos', 'mejores_terceros', 'equipos_por_grupo'])

# %%
resultado["equipos_por_grupo"]
# Out:
# {('A', '1º'): 'Mexico',
#  ('B', '1º'): 'Switzerland',
#  ('C', '1º'): 'Morocco',
#  ('D', '1º'): 'Turkey',
#  ('E', '1º'): 'Ecuador',
#  ('F', '1º'): 'Japan',
#  ('G', '1º'): 'New Zealand',
#  ('H', '1º'): 'Spain',
#  ('I', '1º'): 'Senegal',
#  ('J', '1º'): 'Argentina',
#  ('K', '1º'): 'Colombia',
#  ('L', '1º'): 'Croatia',
#  ('A', '2º'): 'Czech Republic',
#  ('B', '2º'): 'Canada',
#  ('C', '2º'): 'Brazil',
#  ('D', '2º'): 'Paraguay',
#  ('E', '2º'): 'Ivory Coast',
#  ('F', '2º'): 'Netherlands',
#  ('G', '2º'): 'Egypt',
#  ('H', '2º'): 'Uruguay',
#  ('I', '2º'): 'France',
#  ('J', '2º'): 'Jordan',
#  ('K', '2º'): 'Portugal',
#  ('L', '2º'): 'Ghana',
#  ('I', '3º'): 'Norway',
#  ('C', '3º'): 'Scotland',
#  ('A', '3º'): 'South Korea',
#  ('D', '3º'): 'Australia',
#  ('G', '3º'): 'Belgium',
#  ('F', '3º'): 'Tunisia',
#  ('E', '3º'): 'Germany',
#  ('K', '3º'): 'Uzbekistan'}

# %%
from collections import Counter

campeones = []

for _ in range(1000):

    campeones.append(
        simular_mundial()["campeon"]
    )

ranking = Counter(
    campeones
).most_common()

ranking
# Out:
# [('Spain', 251),
#  ('Argentina', 202),
#  ('England', 154),
#  ('Colombia', 72),
#  ('France', 69),
#  ('Netherlands', 62),
#  ('Ecuador', 34),
#  ('Brazil', 30),
#  ('Portugal', 23),
#  ('Croatia', 18),
#  ('Switzerland', 15),
#  ('Germany', 9),
#  ('Turkey', 9),
#  ('Uruguay', 9),
#  ('Norway', 8),
#  ('Canada', 6),
#  ('Morocco', 6),
#  ('Japan', 6),
#  ('Austria', 4),
#  ('Belgium', 4),
#  ('Senegal', 3),
#  ('Paraguay', 3),
#  ('Mexico', 1),
#  ('Panama', 1),
#  ('Iran', 1)]

# %%
from collections import Counter

campeones = []

for _ in range(5000):

    campeones.append(
        simular_mundial()["campeon"]
    )

ranking = Counter(
    campeones
).most_common()

ranking
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[123], line 8
#       4
#       5 for _ in range(5000):
#       6
#       7     campeones.append(
# ----> 8         simular_mundial()["campeon"]
#       9     )
#      10
#      11 ranking = Counter(
#
# Cell In[109], line 10, in simular_mundial()
#       6         primeros,
#       7         segundos,
#       8         terceros,
#       9         cuartos
# ---> 10     ) = simular_fase_grupos(
#      11         grupos
#      12     )
#      13
#
# Cell In[55], line 17, in simular_fase_grupos(grupos)
#      13     cuartos = []
#      14
#      15     for nombre_grupo, equipos in grupos.items():
#      16
# ---> 17         clasificacion, partidos = simular_grupo(
#      18             equipos
#      19         )
#      20
#
# Cell In[46], line 79, in simular_grupo(equipos)
#      75         1,
#      76         len(tabla) + 1
#      77     )
#      78
# ---> 79     tabla = tabla[
#      80         [
#      81             "posicion",
#      82             "team",
#
# File c:\Users\alex_\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\alex_\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6304, in Index._get_indexer_strict(self, key, axis_name)
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6302 self._raise_if_missing(keyarr, indexer, axis_name)
# -> 6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#    6307     keyarr.name = key.name
#
# File c:\Users\alex_\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:1300, in Index.take(self, indices, axis, allow_fill, fill_value, **kwargs)
#    1295     taken = algos.take(
#    1296         values, indices, allow_fill=allow_fill, fill_value=self._na_value
#    1297     )
#    1298 else:
#    1299     # algos.take passes 'axis' keyword which not all EAs accept
# -> 1300     taken = values.take(
#    1301         indices, allow_fill=allow_fill, fill_value=self._na_value
#    1302     )
#    1303 return self._constructor._simple_new(taken, name=self.name)
#
# File c:\Users\alex_\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arrays\arrow\array.py:1629, in ArrowExtensionArray.take(self, indices, allow_fill, fill_value)
#    1627     indices_array = np.copy(indices_array)
#    1628     indices_array[indices_array < 0] += len(self._pa_array)
# -> 1629 return self._from_pyarrow_array(self._pa_array.take(indices_array))
#
# File pyarrow/table.pxi:1083, in pyarrow.lib.ChunkedArray.take()
# -> 1083 'Could not get source, probably due dynamically evaluated source code.'
#
# File c:\Users\alex_\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyarrow\compute.py:508, in take(data, indices, boundscheck, memory_pool)
#     468 """
#     469 Select values (or records) from array- or table-like data given integer
#     470 selection indices.
#    (...)    505 ]
#     506 """
#     507 options = TakeOptions(boundscheck=boundscheck)
# --> 508 return call_function('take', [data, indices], options, memory_pool)
#
# KeyboardInterrupt:

# %%
from collections import Counter

campeones = []

for _ in range(5000):

    campeones.append(
        simular_mundial()["campeon"]
    )

Counter(
    campeones
).most_common(20)

# %%
resultado["equipos_por_grupo"][("A","1º")]
# Out:
# 'Mexico'

# %%
resultado["equipos_por_grupo"][("A","2º")]
# Out:
# 'Czech Republic'

# %%
selecciones.sort_values(
    "elo",
    ascending=False
)[
    ["team", "elo"]
].head(20)
# Out:
#            team     elo
# 28        Spain  2171.0
# 36    Argentina  2113.0
# 32       France  2062.0
# 44      England  2042.0
# 43     Colombia  1998.0
# 8        Brazil  1979.0
# 40     Portugal  1976.0
# 20  Netherlands  1959.0
# 19      Ecuador  1933.0
# 45      Croatia  1933.0
# 35       Norway  1922.0
# 16      Germany  1910.0
# 7   Switzerland  1897.0
# 31      Uruguay  1890.0
# 15       Turkey  1880.0
# 21        Japan  1878.0
# 24      Belgium  1849.0
# 0        Mexico  1835.0
# 13     Paraguay  1833.0
# 9       Morocco  1830.0

# %%
def simular_mundial():

    (
        clasificaciones,
        partidos_grupos,
        primeros,
        segundos,
        terceros,
        cuartos
    ) = simular_fase_grupos(
        grupos
    )

    ranking_terceros = (
        terceros
        .sort_values(
            by=["PTS", "DG", "GF"],
            ascending=False
        )
        .reset_index(
            drop=True
        )
    )

    mejores_terceros = (
        ranking_terceros.head(8)
    )

    equipos_por_grupo = {}

    for _, fila in primeros.iterrows():

        equipos_por_grupo[
            (fila["grupo"], "1º")
        ] = fila["team"]

    for _, fila in segundos.iterrows():

        equipos_por_grupo[
            (fila["grupo"], "2º")
        ] = fila["team"]

    for _, fila in mejores_terceros.iterrows():

        equipos_por_grupo[
            (fila["grupo"], "3º")
        ] = fila["team"]

    terceros_ordenados = (
        mejores_terceros["team"]
        .tolist()
    )

    cruces_terceros = {

        74: (
            equipos_por_grupo[("E", "1º")],
            terceros_ordenados[0]
        ),

        77: (
            equipos_por_grupo[("I", "1º")],
            terceros_ordenados[1]
        ),

        79: (
            equipos_por_grupo[("A", "1º")],
            terceros_ordenados[2]
        ),

        80: (
            equipos_por_grupo[("L", "1º")],
            terceros_ordenados[3]
        ),

        81: (
            equipos_por_grupo[("D", "1º")],
            terceros_ordenados[4]
        ),

        82: (
            equipos_por_grupo[("G", "1º")],
            terceros_ordenados[5]
        ),

        85: (
            equipos_por_grupo[("B", "1º")],
            terceros_ordenados[6]
        ),

        87: (
            equipos_por_grupo[("K", "1º")],
            terceros_ordenados[7]
        )
    }

    cruces_fijos = {

        73: (
            equipos_por_grupo[("A", "2º")],
            equipos_por_grupo[("B", "2º")]
        ),

        75: (
            equipos_por_grupo[("F", "1º")],
            equipos_por_grupo[("C", "2º")]
        ),

        76: (
            equipos_por_grupo[("C", "1º")],
            equipos_por_grupo[("F", "2º")]
        ),

        78: (
            equipos_por_grupo[("E", "2º")],
            equipos_por_grupo[("I", "2º")]
        ),

        83: (
            equipos_por_grupo[("K", "2º")],
            equipos_por_grupo[("L", "2º")]
        ),

        84: (
            equipos_por_grupo[("H", "1º")],
            equipos_por_grupo[("J", "2º")]
        ),

        86: (
            equipos_por_grupo[("J", "1º")],
            equipos_por_grupo[("H", "2º")]
        ),

        88: (
            equipos_por_grupo[("D", "2º")],
            equipos_por_grupo[("G", "2º")]
        )
    }

    partidos_eliminatoria = {}

    for numero, (local, visitante) in cruces_fijos.items():

        partidos_eliminatoria[numero] = {
            "local": local,
            "visitante": visitante
        }

    for numero, (local, visitante) in cruces_terceros.items():

        partidos_eliminatoria[numero] = {
            "local": local,
            "visitante": visitante
        }

    resultados_eliminatoria = {}

    def ganador(numero_partido):

        return resultados_eliminatoria[
            numero_partido
        ]["ganador"]

    def jugar(numero_partido):

        local = partidos_eliminatoria[
            numero_partido
        ]["local"]

        visitante = partidos_eliminatoria[
            numero_partido
        ]["visitante"]

        resultado = simular_eliminatoria(
            local,
            visitante
        )

        resultados_eliminatoria[
            numero_partido
        ] = resultado

    # Dieciseisavos

    for partido in range(73, 89):

        jugar(partido)

    # Octavos

    cruces_octavos = {

        89: (74, 77),
        90: (73, 75),
        91: (76, 78),
        92: (79, 80),

        93: (83, 84),
        94: (81, 82),
        95: (86, 88),
        96: (85, 87)
    }

    for partido, (p1, p2) in cruces_octavos.items():

        resultado = simular_eliminatoria(
            ganador(p1),
            ganador(p2)
        )

        resultados_eliminatoria[
            partido
        ] = resultado

    # Cuartos

    cruces_cuartos = {

        97: (89, 90),

        98: (93, 94),

        99: (91, 92),

        100: (95, 96)
    }

    for partido, (p1, p2) in cruces_cuartos.items():

        resultado = simular_eliminatoria(
            ganador(p1),
            ganador(p2)
        )

        resultados_eliminatoria[
            partido
        ] = resultado

    # Semifinales

    resultado = simular_eliminatoria(
        ganador(97),
        ganador(98)
    )

    resultados_eliminatoria[101] = resultado

    resultado = simular_eliminatoria(
        ganador(99),
        ganador(100)
    )

    resultados_eliminatoria[102] = resultado

# Final

    final = simular_eliminatoria(
        ganador(101),
        ganador(102)
)

    resultados_eliminatoria[104] = final


# Equipos que alcanzan cada ronda

    equipos_16avos = set()

    for partido in range(73, 89):

        equipos_16avos.add(
        partidos_eliminatoria[partido]["local"]
    )

        equipos_16avos.add(
        partidos_eliminatoria[partido]["visitante"]
    )


    equipos_octavos = set()

    for partido in range(89, 97):

        equipos_octavos.add(
        resultados_eliminatoria[partido]["local"]
    )

        equipos_octavos.add(
        resultados_eliminatoria[partido]["visitante"]
    )


    equipos_cuartos = set()

    for partido in range(97, 101):

        equipos_cuartos.add(
        resultados_eliminatoria[partido]["local"]
    )

        equipos_cuartos.add(
        resultados_eliminatoria[partido]["visitante"]
    )


    equipos_semis = set()

    for partido in [101, 102]:

        equipos_semis.add(
        resultados_eliminatoria[partido]["local"]
    )

        equipos_semis.add(
        resultados_eliminatoria[partido]["visitante"]
    )


    equipos_final = {

        resultados_eliminatoria[104]["local"],
        resultados_eliminatoria[104]["visitante"]

}
    return {

    "campeon":
        resultados_eliminatoria[104]["ganador"],

    "equipos_16avos":
        equipos_16avos,

    "equipos_octavos":
        equipos_octavos,

    "equipos_cuartos":
        equipos_cuartos,

    "equipos_semis":
        equipos_semis,

    "equipos_final":
        equipos_final,

    "final":
        resultados_eliminatoria[104],

    "resultados":
        resultados_eliminatoria
}

# %%
resultado = simular_mundial()

resultado.keys()
# Out:
# dict_keys(['campeon', 'equipos_16avos', 'equipos_octavos', 'equipos_cuartos', 'equipos_semis', 'equipos_final', 'final', 'resultados'])

# %% [markdown]
# # Probabilidad de alcanzar cada ronda

# %%
from collections import defaultdict

contador_16avos = defaultdict(int)

contador_octavos = defaultdict(int)

contador_cuartos = defaultdict(int)

contador_semis = defaultdict(int)

contador_final = defaultdict(int)

contador_campeon = defaultdict(int)


n_simulaciones = 1000


for _ in range(n_simulaciones):

    resultado = simular_mundial()

    for equipo in resultado["equipos_16avos"]:

        contador_16avos[equipo] += 1

    for equipo in resultado["equipos_octavos"]:

        contador_octavos[equipo] += 1

    for equipo in resultado["equipos_cuartos"]:

        contador_cuartos[equipo] += 1

    for equipo in resultado["equipos_semis"]:

        contador_semis[equipo] += 1

    for equipo in resultado["equipos_final"]:

        contador_final[equipo] += 1

    contador_campeon[
        resultado["campeon"]
    ] += 1

# %%
equipos = sorted(
    selecciones["team"].unique()
)

probabilidades = []

for equipo in equipos:

    probabilidades.append({

        "team": equipo,

        "16avos":
            contador_16avos[equipo]
            / n_simulaciones * 100,

        "Octavos":
            contador_octavos[equipo]
            / n_simulaciones * 100,

        "Cuartos":
            contador_cuartos[equipo]
            / n_simulaciones * 100,

        "Semifinal":
            contador_semis[equipo]
            / n_simulaciones * 100,

        "Final":
            contador_final[equipo]
            / n_simulaciones * 100,

        "Campeon":
            contador_campeon[equipo]
            / n_simulaciones * 100
    })

probabilidades = pd.DataFrame(
    probabilidades
)

probabilidades = probabilidades.sort_values(
    "Campeon",
    ascending=False
)

probabilidades.head(20)
# Out:
#            team  16avos  Octavos  Cuartos  Semifinal  Final  Campeon
# 40        Spain   100.0     83.3     58.2       50.9   37.1     23.4
# 1     Argentina    99.8     77.0     68.5       52.0   34.5     21.8
# 16      England    99.9     83.8     66.8       45.4   27.9     15.0
# 17       France    99.6     76.4     50.6       32.2   16.0      9.3
# 28  Netherlands    99.3     70.9     52.3       29.7   12.2      5.4
# 6        Brazil    99.3     60.4     36.6       20.5    9.4      4.2
# 9      Colombia    99.6     75.9     45.9       22.9   10.7      3.7
# 14      Ecuador    99.7     69.4     36.1       19.6    9.0      3.3
# 33     Portugal    98.9     61.2     31.5       15.2    6.5      3.0
# 10      Croatia    97.7     54.4     24.2       14.5    6.3      2.5
# 42  Switzerland    99.8     74.8     34.6       12.6    3.8      1.4
# 44       Turkey    92.8     61.1     30.8       10.6    4.5      1.4
# 30       Norway    92.6     51.0     26.5       11.1    3.7      0.8
# 4       Belgium    97.0     61.9     25.9        6.0    1.9      0.8
# 46      Uruguay    95.5     23.9     14.6        5.4    2.4      0.7
# 24        Japan    94.8     43.0     21.1        7.9    2.4      0.7
# 18      Germany    98.4     52.9     22.3        8.8    3.3      0.6
# 32     Paraguay    85.0     51.5     21.7        4.8    1.3      0.5
# 26       Mexico    93.3     46.7     12.9        4.1    1.4      0.4
# 7        Canada    98.2     59.6     21.8        4.5    1.2      0.3

# %%
probabilidades_export = (
    probabilidades
    .round(1)
)

probabilidades_export.to_csv(
    "probabilidades_mundial.csv",
    index=False
)
probabilidades.to_excel(
    "probabilidades_mundial.xlsx",
    index=False
)

# %%
pd.read_csv(
    "probabilidades_mundial.csv"
).head()
# Out:
#           team  16avos  Octavos  Cuartos  Semifinal  Final  Campeon
# 0        Spain   100.0     83.3     58.2       50.9   37.1     23.4
# 1    Argentina    99.8     77.0     68.5       52.0   34.5     21.8
# 2      England    99.9     83.8     66.8       45.4   27.9     15.0
# 3       France    99.6     76.4     50.6       32.2   16.0      9.3
# 4  Netherlands    99.3     70.9     52.3       29.7   12.2      5.4

# %%
probabilidades = probabilidades.round(2)

probabilidades.head(20)
# Out:
#            team  16avos  Octavos  Cuartos  Semifinal  Final  Campeon
# 40        Spain   100.0     83.3     58.2       50.9   37.1     23.4
# 1     Argentina    99.8     77.0     68.5       52.0   34.5     21.8
# 16      England    99.9     83.8     66.8       45.4   27.9     15.0
# 17       France    99.6     76.4     50.6       32.2   16.0      9.3
# 28  Netherlands    99.3     70.9     52.3       29.7   12.2      5.4
# 6        Brazil    99.3     60.4     36.6       20.5    9.4      4.2
# 9      Colombia    99.6     75.9     45.9       22.9   10.7      3.7
# 14      Ecuador    99.7     69.4     36.1       19.6    9.0      3.3
# 33     Portugal    98.9     61.2     31.5       15.2    6.5      3.0
# 10      Croatia    97.7     54.4     24.2       14.5    6.3      2.5
# 42  Switzerland    99.8     74.8     34.6       12.6    3.8      1.4
# 44       Turkey    92.8     61.1     30.8       10.6    4.5      1.4
# 30       Norway    92.6     51.0     26.5       11.1    3.7      0.8
# 4       Belgium    97.0     61.9     25.9        6.0    1.9      0.8
# 46      Uruguay    95.5     23.9     14.6        5.4    2.4      0.7
# 24        Japan    94.8     43.0     21.1        7.9    2.4      0.7
# 18      Germany    98.4     52.9     22.3        8.8    3.3      0.6
# 32     Paraguay    85.0     51.5     21.7        4.8    1.3      0.5
# 26       Mexico    93.3     46.7     12.9        4.1    1.4      0.4
# 7        Canada    98.2     59.6     21.8        4.5    1.2      0.3

# %% [markdown]
# # Resultados Monte Carlo
#
# Se realizaron 1000 simulaciones completas del Mundial 2026.
#
# Las probabilidades obtenidas representan la frecuencia con la que cada selección alcanzó cada ronda del torneo.
#
# Las selecciones con mayor probabilidad de proclamarse campeonas fueron:
#
# 1. España
# 2. Argentina
# 3. Inglaterra
# 4. Francia
# 5. Países Bajos

# %%
selecciones.sort_values(
    "rank"
)[
    ["team", "rank"]
].head(20)
# Out:
#              team  rank
# 28          Spain   1.0
# 36      Argentina   2.0
# 32         France   3.0
# 44        England   4.0
# 8          Brazil   5.0
# 40       Portugal   6.0
# 20    Netherlands   7.0
# 24        Belgium   8.0
# 16        Germany   9.0
# 45        Croatia  10.0
# 9         Morocco  11.0
# 43       Colombia  13.0
# 12  United States  14.0
# 0          Mexico  15.0
# 31        Uruguay  16.0
# 7     Switzerland  17.0
# 21          Japan  18.0
# 33        Senegal  19.0
# 26           Iran  20.0
# 2     South Korea  22.0

# %% [markdown]
# IDEA PARA LA VISUALIZACION

# %%
from collections import Counter

campeones = []

for _ in range(10000):

    campeones.append(
        simular_mundial()["campeon"]
    )

ranking = Counter(
    campeones
).most_common()

# %%
ranking_df = pd.DataFrame(
    ranking,
    columns=[
        "team",
        "titulos"
    ]
)

ranking_df.to_csv(
    "montecarlo_10000.csv",
    index=False
)

# %% [markdown]
# ## Simulación completa del Mundial
#
# Esta función ejecutará todas las fases del torneo:
#
# - Fase de grupos
# - Clasificación a eliminatorias
# - Fase final
#
# y devolverá el campeón.

# %%
def simular_mundial():

    (
        clasificaciones,
        partidos_grupos,
        primeros,
        segundos,
        terceros,
        cuartos
    ) = simular_fase_grupos(
        grupos
    )

    ranking_terceros = (
        terceros
        .sort_values(
            by=["PTS", "DG", "GF"],
            ascending=False
        )
        .reset_index(
            drop=True
        )
    )

    mejores_terceros = (
        ranking_terceros
        .head(8)
    )

    return {
        "clasificaciones": clasificaciones,
        "primeros": primeros,
        "segundos": segundos,
        "terceros": terceros,
        "mejores_terceros": mejores_terceros
    }
